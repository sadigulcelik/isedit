# %% [markdown]
# ## Notebook for testing functions

# %%
import sys
import os
from IPython.display import Image
sys.path.insert(0, os.path.join(os.getcwd(),"src"))
from Base import *

# %%
voices = []
voices.append("c' d' e' f' g' a' b' c''")
keys, freqs = convertNotes(voices)
playNotes(freqs)
displayNotes(voices)
